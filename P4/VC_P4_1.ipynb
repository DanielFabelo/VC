# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.7/877.7 kB 51.6 MB/s eta 0:00:00
# ...

# %%
import cv2
import math

from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo11n.pt')

model.train(data='/content/drive/MyDrive/dataset/data.yaml', epochs=50)
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.val()
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/val/labels.cache... 81 images, 0 backgrounds, 0 corrupt: 100%|██████████| 81/81 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 51, len(boxes) = 81. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.40it/s]
#                    all         81         81      0.987          1      0.994      0.859
# Speed: 0.7ms preprocess, 13.2ms inference, 0.0ms loss, 8.8ms postprocess per image
# Results saved to runs/detect/train32

# %%
from IPython.display import Image
from IPython.display import display
x = Image(filename='/content/runs/detect/train32/F1_curve.png')
y = Image(filename='/content/runs/detect/train32/PR_curve.png')
z = Image(filename='/content/runs/detect/train32/confusion_matrix.png')
display(x, y,z)
